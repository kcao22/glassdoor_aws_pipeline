# %%
import pandas as pd

# %%
input_df = pd.read_json('../Data/Raw_20238901.json')

# %%
input_df
# Out:
#                   CompanyName       JobTitle  JobLocation  EasyApply  \
# 0                                                                NaN
# 1  Alameda Health System\n3.5  Data Engineer  Oakland, CA        NaN
#
#                                       JobDescription  \
# 0  Description:\n*This is NOT a remote position. ...
# 1  SUMMARY: Functions as a database leader, respo...
#
#                         JobSalary  CompanyRating              CompanySize  \
# 0   $73K - $103K (Glassdoor est.)            2.8      51 to 200 Employees
# 1  $131K - $185K (Glassdoor est.)            3.5  5001 to 10000 Employees
#
#          CompanyType       CompanySector  CompanyYearFounded  \
# 0  Company - Private  Retail & Wholesale                1985
# 1           Hospital          Healthcare                1864
#
#                     CompanyIndustry             CompanyRevenue
# 0                         Wholesale    $5 to $25 million (USD)
# ...

# %%
input_df = input_df[(input_df['CompanyName'] != None) & (input_df['JobTitle'] != None) & (input_df['JobLocation'] != None)]

# %%
input_df
# Out:
#                   CompanyName       JobTitle  JobLocation  EasyApply  \
# 0                                                                NaN
# 1  Alameda Health System\n3.5  Data Engineer  Oakland, CA        NaN
#
#                                       JobDescription  \
# 0  Description:\n*This is NOT a remote position. ...
# 1  SUMMARY: Functions as a database leader, respo...
#
#                         JobSalary  CompanyRating              CompanySize  \
# 0   $73K - $103K (Glassdoor est.)            2.8      51 to 200 Employees
# 1  $131K - $185K (Glassdoor est.)            3.5  5001 to 10000 Employees
#
#          CompanyType       CompanySector  CompanyYearFounded  \
# 0  Company - Private  Retail & Wholesale                1985
# 1           Hospital          Healthcare                1864
#
#                     CompanyIndustry             CompanyRevenue
# 0                         Wholesale    $5 to $25 million (USD)
# ...

# %%
input_df = input_df.loc[((input_df['CompanyName'] is not None) & 
                            (input_df['JobTitle'] is not None) & 
                            (input_df['JobLocation'] is not None))
                            | ((input_df['CompanyName'] != '') & 
                            (input_df['JobTitle'] != '') & 
                            (input_df['JobLocation'] != ''))]

# %%
input_df
# Out:
#                   CompanyName       JobTitle  JobLocation  EasyApply  \
# 0                                                                NaN
# 1  Alameda Health System\n3.5  Data Engineer  Oakland, CA        NaN
#
#                                       JobDescription  \
# 0  Description:\n*This is NOT a remote position. ...
# 1  SUMMARY: Functions as a database leader, respo...
#
#                         JobSalary  CompanyRating              CompanySize  \
# 0   $73K - $103K (Glassdoor est.)            2.8      51 to 200 Employees
# 1  $131K - $185K (Glassdoor est.)            3.5  5001 to 10000 Employees
#
#          CompanyType       CompanySector  CompanyYearFounded  \
# 0  Company - Private  Retail & Wholesale                1985
# 1           Hospital          Healthcare                1864
#
#                     CompanyIndustry             CompanyRevenue
# 0                         Wholesale    $5 to $25 million (USD)
# ...

# %%
input_df.iloc[0]['CompanyName']
# Out:
# ''

# %%
input_df = input_df[((input_df['CompanyName'] != '') & (input_df['JobTitle'] != '') & (input_df['JobLocation'] != '')) | ((input_df['CompanyName'] is not None) & (input_df['JobTitle'] is not None) & (input_df['JobLocation'] is not None))]

# %%
input_df
# Out:
#                   CompanyName       JobTitle  JobLocation  EasyApply  \
# 0                                                                NaN
# 1  Alameda Health System\n3.5  Data Engineer  Oakland, CA        NaN
#
#                                       JobDescription  \
# 0  Description:\n*This is NOT a remote position. ...
# 1  SUMMARY: Functions as a database leader, respo...
#
#                         JobSalary  CompanyRating              CompanySize  \
# 0   $73K - $103K (Glassdoor est.)            2.8      51 to 200 Employees
# 1  $131K - $185K (Glassdoor est.)            3.5  5001 to 10000 Employees
#
#          CompanyType       CompanySector  CompanyYearFounded  \
# 0  Company - Private  Retail & Wholesale                1985
# 1           Hospital          Healthcare                1864
#
#                     CompanyIndustry             CompanyRevenue
# 0                         Wholesale    $5 to $25 million (USD)
# ...

# %%
test1 = pd.read_json('../Data/Raw_20230704.json')

# %%
test1
# Out:
#                     CompanyName              JobTitle        JobLocation  \
# 0   Drexel Building Supply\n2.8         Data Engineer  Campbellsport, WI
# 1    Alameda Health System\n3.5         Data Engineer        Oakland, CA
# 2                FM Global\n3.7         Data Engineer       Johnston, RI
# 3           Liberty Mutual\n3.8         Data Engineer         Boston, MA
# 4        Double Line, Inc.\n4.1         Data Engineer      Nashville, TN
# ..                          ...                   ...                ...
# 73                         None  Senior Data Engineer               None
# 74                         None  Senior Data Engineer               None
# 75                         None  Senior Data Engineer               None
# 76       Certec Consulting\n5.0  Senior Data Engineer        Madison, WI
# 77                         None  Senior Data Engineer               None
#
#     EasyApply                                     JobDescription  \
# ...

# %%
test2 = test1[~test1['CompanyName'].isnull() & ~test1['JobTitle'].isnull() & ~test1['JobLocation'].isnull()]

# %%
test2
# Out:
#                       CompanyName              JobTitle        JobLocation  \
# 0     Drexel Building Supply\n2.8         Data Engineer  Campbellsport, WI
# 1      Alameda Health System\n3.5         Data Engineer        Oakland, CA
# 2                  FM Global\n3.7         Data Engineer       Johnston, RI
# 3             Liberty Mutual\n3.8         Data Engineer         Boston, MA
# 4          Double Line, Inc.\n4.1         Data Engineer      Nashville, TN
# ..                            ...                   ...                ...
# 62                 Medtronic\n3.9  Senior Data Engineer        Fridley, MN
# 63  Thermo Fisher Scientific\n3.7  Senior Data Engineer      Massachusetts
# 64             Acuity Brands\n3.6  Senior Data Engineer        Conyers, GA
# 68               Blue Yonder\n4.1  Senior Data Engineer         Dallas, TX
# 76         Certec Consulting\n5.0  Senior Data Engineer        Madison, WI
#
#     EasyApply                                     JobDescription  \
# ...

# %%
test3 = test1.dropna(subset=['CompanyName', 'JobTitle', 'JobLocation'], thresh=2)

# %%
test3
# Out:
#                       CompanyName              JobTitle        JobLocation  \
# 0     Drexel Building Supply\n2.8         Data Engineer  Campbellsport, WI
# 1      Alameda Health System\n3.5         Data Engineer        Oakland, CA
# 2                  FM Global\n3.7         Data Engineer       Johnston, RI
# 3             Liberty Mutual\n3.8         Data Engineer         Boston, MA
# 4          Double Line, Inc.\n4.1         Data Engineer      Nashville, TN
# ..                            ...                   ...                ...
# 62                 Medtronic\n3.9  Senior Data Engineer        Fridley, MN
# 63  Thermo Fisher Scientific\n3.7  Senior Data Engineer      Massachusetts
# 64             Acuity Brands\n3.6  Senior Data Engineer        Conyers, GA
# 68               Blue Yonder\n4.1  Senior Data Engineer         Dallas, TX
# 76         Certec Consulting\n5.0  Senior Data Engineer        Madison, WI
#
#     EasyApply                                     JobDescription  \
# ...
